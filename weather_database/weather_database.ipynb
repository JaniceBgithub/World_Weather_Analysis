# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the time module.
import time

# Import the requests library.
import requests

# Import the API key.
from config1 import weather_API_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_API_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
weather_API_key
# Out:
# '87bce9b45001c56ffe1ebc3e891c8ab1'

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# ['attawapiskat',
#  'cherskiy',
#  'ostrovnoy',
#  'college',
#  'farafangana',
#  'estelle',
#  'kodiak',
#  'vostok',
#  'waipawa',
#  'carnarvon',
#  'new norfolk',
#  'amderma',
#  'saldanha',
#  'ushuaia',
#  'punta arenas',
#  'murdochville',
#  'port alfred',
#  'castro',
#  'mataura',
#  'east london',
#  'hilo',
#  'sosnogorsk',
#  'tiksi',
#  'tsihombe',
#  'saint george',
#  'bengkulu',
#  'yellowknife',
#  'hamilton',
#  'qaanaaq',
#  'saint-paul',
#  'rikitea',
#  'taolanaro',
#  'kayerkan',
#  'esperance',
#  'birjand',
#  'quatre cocos',
#  'doha',
#  'chokurdakh',
#  'kapaa',
#  'galveston',
#  'sitka',
#  'salalah',
#  'illoqqortoormiut',
#  'barentsburg',
#  'banda aceh',
#  'butaritari',
#  'grindavik',
#  'soure',
#  'bluff',
#  'san ignacio',
#  'husavik',
#  'barawe',
#  'cabo san lucas',
#  'hithadhoo',
#  'provideniya',
#  'touros',
#  'tasiilaq',
#  'arraial do cabo',
#  'marcona',
#  'grand gaube',
#  'ribeira grande',
#  'havelock',
#  'faanui',
#  'galesong',
#  'barrow',
#  'palabuhanratu',
#  'souillac',
#  'hermanus',
#  'kaitangata',
#  'lasem',
#  'port lincoln',
#  'borazjan',
#  'khatanga',
#  'mwense',
#  'puerto ayora',
#  'pevek',
#  'alburikent',
#  'felidhoo',
#  'ossora',
#  'cayenne',
#  'umm kaddadah',
#  'praya',
#  'hailey',
#  'vangaindrano',
#  'ginda',
#  'sisimiut',
#  'jasper',
#  'albany',
#  'sterling',
#  'bethel',
#  'mandalgovi',
#  'vaini',
#  'inderborskiy',
#  'nguiu',
#  'leningradskiy',
#  'mutsu',
#  'petropavlovsk-kamchatskiy',
#  'haines junction',
#  'yulara',
#  'ambilobe',
#  'dikson',
#  'auki',
#  'tuktoyaktuk',
#  'puerto escondido',
#  'upernavik',
#  'coihaique',
#  'bargal',
#  'mumbwa',
#  'hobart',
#  'flinders',
#  'mar del plata',
#  'ancud',
#  'norman wells',
#  'keti bandar',
#  'bani',
#  'odweyne',
#  'walvis bay',
#  'panshi',
#  'san patricio',
#  'cap malheureux',
#  'cidreira',
#  'usinsk',
#  'avera',
#  'osorno',
#  'atuona',
#  'novo aripuana',
#  'busselton',
#  'cape town',
#  'bambous virieux',
#  'narsaq',
#  'port-cartier',
#  'itoman',
#  'saint-philippe',
#  'aborlan',
#  'alofi',
#  'longyearbyen',
#  'sambava',
#  'sorland',
#  'zhuhai',
#  'georgetown',
#  'kachikau',
#  'hayvoron',
#  'mount gambier',
#  'klaksvik',
#  'lorengau',
#  'amazar',
#  'yerbogachen',
#  'clyde river',
#  'ucluelet',
#  'havre-saint-pierre',
#  'san rafael',
#  'el porvenir',
#  'urumqi',
#  'bredasdorp',
#  'bonavista',
#  'bandiagara',
#  'pisco',
#  'laredo',
#  'waingapu',
#  'antsohihy',
#  'ust-kut',
#  'yarada',
#  'dudinka',
#  'abha',
#  'beloha',
#  'tuatapere',
#  'trairi',
#  'thompson',
#  'belushya guba',
#  'luderitz',
#  'temnikov',
#  'chuy',
#  'manokwari',
#  'marsa matruh',
#  'mahebourg',
#  'mys shmidta',
#  'louisbourg',
#  'lompoc',
#  'grand river south east',
#  'vanavara',
#  'gazanjyk',
#  'albina',
#  'adrar',
#  'avarua',
#  'shamkhal',
#  'tuxtla',
#  'slave lake',
#  'nikolskoye',
#  'umzimvubu',
#  'lazaro cardenas',
#  'linxia',
#  'tateyama',
#  'aripuana',
#  'waddan',
#  'swellendam',
#  'mayo',
#  'piacabucu',
#  'qaqortoq',
#  'bluefield',
#  'reitz',
#  'nemuro',
#  'ginir',
#  'northam',
#  'lavrentiya',
#  'gigmoto',
#  'bulungu',
#  'ulaangom',
#  'ilulissat',
#  'cam ranh',
#  'kirakira',
#  'kankon',
#  'sarkand',
#  'nelson bay',
#  'acapulco',
#  'mount isa',
#  'hare bay',
#  'ust-maya',
#  'sol-iletsk',
#  'neryungri',
#  'khowai',
#  'mirnyy',
#  'puerto carreno',
#  'sierra vista',
#  'san quintin',
#  'tumannyy',
#  'qingdao',
#  'launceston',
#  'torbay',
#  'kondopoga',
#  'churapcha',
#  'jamestown',
#  'hihifo',
#  'asyut',
#  'gizo',
#  'sabha',
#  'tigil',
#  'alyangula',
#  'mana',
#  'kijang',
#  'san policarpo',
#  'ponta do sol',
#  'mongoumba',
#  'amapa',
#  'meyungs',
#  'alice springs',
#  'port hedland',
#  'lagoa',
#  'chitapur',
#  'victoria',
#  'tiarei',
#  'bilma',
#  'gogrial',
#  'harper',
#  'nanortalik',
#  'katsuura',
#  'imbituba',
#  'krasnaya gora',
#  'kantang',
#  'saleaula',
#  'borisoglebsk',
#  'port elizabeth',
#  'rosetta',
#  'boa vista',
#  'marzuq',
#  'vaitupu',
#  'ahipara',
#  'rapid valley',
#  'sao joao da barra',
#  'singaraja',
#  'axim',
#  'barbar',
#  'tromso',
#  'sile',
#  'gushikawa',
#  'trogir',
#  'fortuna',
#  'adeje',
#  'bidar',
#  'lagos',
#  'murray bridge',
#  'lebu',
#  'tidore',
#  'kawalu',
#  'slobodskoy',
#  'pervomayskiy',
#  'rawannawi',
#  'north bend',
#  'elizabeth city',
#  'taksimo',
#  'chapleau',
#  'melito di porto salvo',
#  'half moon bay',
#  'north platte',
#  'alghero',
#  'yanan',
#  'broome',
#  'airai',
#  'ushumun',
#  'abnub',
#  'lodwar',
#  'aksu',
#  'verkhnevilyuysk',
#  'simbahan',
#  'abu samrah',
#  'okhotsk',
#  'naze',
#  'ocala',
#  'sigli',
#  'el badari',
#  'kirksville',
#  'zeya',
#  'anzio',
#  'talnakh',
#  'shahr-e babak',
#  'ambon',
#  'lieksa',
#  'staryy nadym',
#  'kulhudhuffushi',
#  'iqaluit',
#  'rawson',
#  'pacora',
#  'burgeo',
#  'graaff-reinet',
#  'hambantota',
#  'impfondo',
#  'foz',
#  'gat',
#  'aranjuez',
#  'aconibe',
#  'borovoy',
#  'poum',
#  'isoka',
#  'ust-kuyga',
#  'babanusah',
#  'gamba',
#  'hanting',
#  'udachnyy',
#  'la ronge',
#  'najran',
#  'bathsheba',
#  'nome',
#  'beringovskiy',
#  'media luna',
#  'atar',
#  'baglung',
#  'dasoguz',
#  'geraldton',
#  'aklavik',
#  'malwan',
#  'belogorsk',
#  'orlandia',
#  'los llanos de aridane',
#  'manado',
#  'katangli',
#  'saint-pierre',
#  'linfen',
#  'uthal',
#  'kinablangan',
#  'margate',
#  'boqueirao',
#  'maceio',
#  'nyimba',
#  'tiznit',
#  'talaya',
#  'kavaratti',
#  'lokosovo',
#  'shimoda',
#  'ovalle',
#  'muisne',
#  'raudeberg',
#  'teeli',
#  'comodoro rivadavia',
#  'oranjemund',
#  'turbat',
#  'coahuayana',
#  'kourou',
#  'portland',
#  'dingle',
#  'brandon',
#  'keelung',
#  'sistranda',
#  'kindu',
#  'seymchan',
#  'blue springs',
#  'san juan de abajo',
#  'korla',
#  'burnie',
#  'namatanai',
#  'carlsbad',
#  'yar-sale',
#  'pascagoula',
#  'ayagoz',
#  'turukhansk',
#  'kumano',
#  'worthington',
#  'tautira',
#  'camopi',
#  'tostamaa',
#  'santa isabel do rio negro',
#  'akyab',
#  'durban',
#  'qeshm',
#  'byron bay',
#  'dogondoutchi',
#  'asopos',
#  'kavieng',
#  'totness',
#  'svetlyy',
#  'saskylakh',
#  'guerrero negro',
#  'vikhorevka',
#  'madimba',
#  'buraydah',
#  'kushmurun',
#  'kununurra',
#  'matagami',
#  'artyom',
#  'lata',
#  'buchanan',
#  'kropotkin',
#  'kastamonu',
#  'bonfim',
#  'san felipe',
#  'warqla',
#  'hofn',
#  'faya',
#  'rio gallegos',
#  'zakamensk',
#  'tuggurt',
#  'kruisfontein',
#  'teguise',
#  'qasigiannguit',
#  'strezhevoy',
#  'padang',
#  'brae',
#  'acari',
#  'el carmen',
#  'natchitoches',
#  'jalu',
#  'sunggal',
#  'kutum',
#  'veraval',
#  'caravelas',
#  'ciudad bolivar',
#  'baherden',
#  'ulvila',
#  'yamada',
#  'balkanabat',
#  'kristinehamn',
#  'severo-kurilsk',
#  'isla vista',
#  'pedernales',
#  'treinta y tres',
#  'hervey bay',
#  'autun',
#  'galiwinku',
#  'rudbar',
#  'bacuit',
#  'chapais',
#  'maningrida',
#  'saint-augustin',
#  'huarmey',
#  'norfolk',
#  'pokhara',
#  'nzega',
#  'khonuu',
#  'sentyabrskiy',
#  'algete',
#  'toliary',
#  'falealupo',
#  'numan',
#  'takoradi',
#  'trincomalee',
#  'kamenskoye',
#  'garowe',
#  'mareeba',
#  'santa ana',
#  'oga',
#  'urdzhar',
#  'codrington',
#  'letlhakeng',
#  'ratnagiri',
#  'vila franca do campo',
#  'mogadishu',
#  'rendsburg',
#  'east foothills',
#  'luangwa',
#  'jumla',
#  'torit',
#  'sosnovo-ozerskoye',
#  'nizwa',
#  'aranda de duero',
#  'carlisle',
#  'tottori',
#  'mutsamudu',
#  'kahului',
#  'salekhard',
#  'labuhan',
#  'tinambacan',
#  'narodychi',
#  'mwanza',
#  'victor harbor',
#  'esna',
#  'pietarsaari',
#  'coquimbo',
#  'houma',
#  'belaya gora',
#  'thinadhoo',
#  'bakchar',
#  'tempio pausania',
#  'skjervoy',
#  'gardan diwal',
#  'bud',
#  'broken hill',
#  'winnemucca',
#  'bubaque',
#  'tadine',
#  'tafresh',
#  'maiduguri',
#  'pacific grove',
#  'hasaki',
#  'vicente guerrero',
#  'oriximina',
#  'pitimbu',
#  'jiexiu',
#  'meadow lake',
#  'gisborne',
#  'makakilo city',
#  'sao joao do piaui',
#  'vardo',
#  'jatiroto',
#  'cozumel',
#  'port augusta',
#  'grand forks',
#  'chicama',
#  'teixoso',
#  'itarema',
#  'bandar',
#  'nagornyy',
#  'mogadouro',
#  'joroan',
#  'constitucion',
#  'kilosa',
#  'mackay',
#  'erzincan',
#  'tikapur',
#  'port macquarie',
#  'xuddur',
#  'sibolga',
#  'kampong cham',
#  'concordia',
#  'buenos aires',
#  'komsomolskiy',
#  'capuluan',
#  'bara',
#  'kazalinsk',
#  'karauzyak',
#  'san juan',
#  'chama',
#  'belyy yar',
#  'pizarro',
#  'coari',
#  'tucupita',
#  'suruc',
#  'dubai',
#  'aras',
#  'otane',
#  'benghazi',
#  'parabel',
#  'mazagao',
#  'corinto',
#  'qom',
#  'nouakchott',
#  'meulaboh',
#  'san cristobal',
#  'kalamare',
#  'tura',
#  'sinnamary',
#  'hope',
#  'vavozh',
#  'hitoyoshi',
#  'dakar',
#  'anadyr',
#  'nara',
#  'zheshart',
#  'pekan',
#  'opuwo',
#  'nova olimpia',
#  'taganak',
#  'lasa',
#  'pochutla',
#  'peniche',
#  'niksic',
#  'mehamn',
#  'hobyo',
#  'vestmanna',
#  'nenjiang',
#  'isangel',
#  'vanderhoof',
#  'xingyi',
#  'karratha',
#  'zhigansk',
#  'pafos',
#  'portlethen',
#  'landang',
#  'piet retief',
#  'hualmay',
#  'luchenza',
#  'nioki',
#  'sao filipe',
#  'esmeraldas',
#  'prince rupert',
#  'adre',
#  'itamaraca',
#  'nizhneyansk',
#  'harnoli',
#  'karaul',
#  'ust-nera',
#  'shchelyayur',
#  'biograd na moru',
#  'gavrilov posad',
#  'dujuma',
#  'douentza',
#  'bababe',
#  'roebourne',
#  'ponta delgada',
#  'sao gotardo',
#  'charlottesville',
#  'cabedelo',
#  'caete',
#  'stavern',
#  'rundu',
#  'ondorhaan',
#  'caronport',
#  'maldonado',
#  'potiskum',
#  'ilorin',
#  'tulsipur',
#  'bodden town',
#  'sedelnikovo',
#  'saryshagan',
#  'nanakuli',
#  'samusu',
#  'ongandjera',
#  'anamur',
#  'vao',
#  'tornio',
#  'guilin',
#  'nortelandia',
#  'yining',
#  'dunedin',
#  'pangnirtung',
#  'aykhal',
#  'de-kastri',
#  'rocha',
#  'beppu',
#  'riyadh',
#  'alihe',
#  'nisia floresta',
#  'shenjiamen',
#  'talavera',
#  'gurupi',
#  'santiago del estero',
#  'samarai',
#  'vitim',
#  'bocaiuva',
#  'south lake tahoe',
#  'egvekinot',
#  'samalaeulu',
#  'formosa do rio preto',
#  'vila velha',
#  'taltal',
#  'todos santos',
#  'yarmouth',
#  'stockelsdorf',
#  'altay',
#  'springbok',
#  'palmer',
#  'lamar',
#  'toora-khem',
#  'caraballeda',
#  'mahon',
#  'werda',
#  'matara',
#  'fuling',
#  'kenai',
#  'kuche',
#  'taft',
#  'maumere',
#  'pandan',
#  'mahajanga',
#  'lulea',
#  'ngukurr',
#  'marawi',
#  'baia de aries',
#  'muroto',
#  'himora',
#  'gondanglegi',
#  'port hardy',
#  'carutapera',
#  'ponca city',
#  'tokur',
#  'saint anthony',
#  'bollnas',
#  'pihani',
#  'tocopilla',
#  'ntungamo',
#  'berlevag',
#  'lingao',
#  'nalut',
#  'iringa',
#  'barahona',
#  'nizhniy kuranakh',
#  'laurel',
#  'ayios matthaios',
#  'gimli',
#  'santa cruz',
#  'luchegorsk',
#  'saint marys',
#  'whitefish',
#  'causapscal',
#  'wanning',
#  'pula',
#  'lentekhi',
#  'aksay',
#  'bukachacha',
#  'aix-en-provence',
#  'hovd',
#  'daru',
#  'paita',
#  'pangkalanbuun',
#  'vakhrushev',
#  'colares',
#  'henties bay',
#  'iskateley',
#  'ixtapa',
#  'noumea',
#  'tabriz',
#  'katherine',
#  'ordu',
#  'makat',
#  'uvat',
#  'prado',
#  'talas',
#  'te anau']

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
  
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
 
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0].get('description')
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
       
        # Append the city information into city_data list.
                      
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description,                          
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | cherskiy
# Processing Record 3 of Set 1 | ostrovnoy
# Processing Record 4 of Set 1 | college
# Processing Record 5 of Set 1 | farafangana
# Processing Record 6 of Set 1 | estelle
# Processing Record 7 of Set 1 | kodiak
# Processing Record 8 of Set 1 | vostok
# Processing Record 9 of Set 1 | waipawa
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 1 | saldanha
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | murdochville
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | sosnogorsk
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 1 | saint george
# Processing Record 26 of Set 1 | bengkulu
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | hamilton
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | saint-paul
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | kayerkan
# Processing Record 34 of Set 1 | esperance
# Processing Record 35 of Set 1 | birjand
# Processing Record 36 of Set 1 | quatre cocos
# Processing Record 37 of Set 1 | doha
# Processing Record 38 of Set 1 | chokurdakh
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | galveston
# Processing Record 41 of Set 1 | sitka
# Processing Record 42 of Set 1 | salalah
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 1 | banda aceh
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | grindavik
# Processing Record 48 of Set 1 | soure
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | san ignacio
# Processing Record 1 of Set 2 | husavik
# Processing Record 2 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 2 | cabo san lucas
# Processing Record 4 of Set 2 | hithadhoo
# Processing Record 5 of Set 2 | provideniya
# Processing Record 6 of Set 2 | touros
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 2 | grand gaube
# Processing Record 11 of Set 2 | ribeira grande
# Processing Record 12 of Set 2 | havelock
# Processing Record 13 of Set 2 | faanui
# Processing Record 14 of Set 2 | galesong
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 2 | souillac
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | lasem
# Processing Record 21 of Set 2 | port lincoln
# Processing Record 22 of Set 2 | borazjan
# Processing Record 23 of Set 2 | khatanga
# Processing Record 24 of Set 2 | mwense
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | pevek
# Processing Record 27 of Set 2 | alburikent
# Processing Record 28 of Set 2 | felidhoo
# City not found. Skipping...
# Processing Record 29 of Set 2 | ossora
# Processing Record 30 of Set 2 | cayenne
# Processing Record 31 of Set 2 | umm kaddadah
# Processing Record 32 of Set 2 | praya
# Processing Record 33 of Set 2 | hailey
# Processing Record 34 of Set 2 | vangaindrano
# Processing Record 35 of Set 2 | ginda
# Processing Record 36 of Set 2 | sisimiut
# Processing Record 37 of Set 2 | jasper
# Processing Record 38 of Set 2 | albany
# Processing Record 39 of Set 2 | sterling
# Processing Record 40 of Set 2 | bethel
# Processing Record 41 of Set 2 | mandalgovi
# Processing Record 42 of Set 2 | vaini
# Processing Record 43 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 44 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 2 | leningradskiy
# Processing Record 46 of Set 2 | mutsu
# Processing Record 47 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 2 | haines junction
# Processing Record 49 of Set 2 | yulara
# Processing Record 50 of Set 2 | ambilobe
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | auki
# Processing Record 3 of Set 3 | tuktoyaktuk
# Processing Record 4 of Set 3 | puerto escondido
# Processing Record 5 of Set 3 | upernavik
# Processing Record 6 of Set 3 | coihaique
# Processing Record 7 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 3 | mumbwa
# Processing Record 9 of Set 3 | hobart
# Processing Record 10 of Set 3 | flinders
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | ancud
# Processing Record 13 of Set 3 | norman wells
# Processing Record 14 of Set 3 | keti bandar
# Processing Record 15 of Set 3 | bani
# Processing Record 16 of Set 3 | odweyne
# Processing Record 17 of Set 3 | walvis bay
# Processing Record 18 of Set 3 | panshi
# Processing Record 19 of Set 3 | san patricio
# Processing Record 20 of Set 3 | cap malheureux
# Processing Record 21 of Set 3 | cidreira
# Processing Record 22 of Set 3 | usinsk
# Processing Record 23 of Set 3 | avera
# Processing Record 24 of Set 3 | osorno
# Processing Record 25 of Set 3 | atuona
# Processing Record 26 of Set 3 | novo aripuana
# Processing Record 27 of Set 3 | busselton
# Processing Record 28 of Set 3 | cape town
# Processing Record 29 of Set 3 | bambous virieux
# Processing Record 30 of Set 3 | narsaq
# Processing Record 31 of Set 3 | port-cartier
# Processing Record 32 of Set 3 | itoman
# Processing Record 33 of Set 3 | saint-philippe
# Processing Record 34 of Set 3 | aborlan
# Processing Record 35 of Set 3 | alofi
# Processing Record 36 of Set 3 | longyearbyen
# Processing Record 37 of Set 3 | sambava
# Processing Record 38 of Set 3 | sorland
# Processing Record 39 of Set 3 | zhuhai
# Processing Record 40 of Set 3 | georgetown
# Processing Record 41 of Set 3 | kachikau
# City not found. Skipping...
# Processing Record 42 of Set 3 | hayvoron
# Processing Record 43 of Set 3 | mount gambier
# Processing Record 44 of Set 3 | klaksvik
# Processing Record 45 of Set 3 | lorengau
# Processing Record 46 of Set 3 | amazar
# Processing Record 47 of Set 3 | yerbogachen
# Processing Record 48 of Set 3 | clyde river
# Processing Record 49 of Set 3 | ucluelet
# Processing Record 50 of Set 3 | havre-saint-pierre
# Processing Record 1 of Set 4 | san rafael
# Processing Record 2 of Set 4 | el porvenir
# Processing Record 3 of Set 4 | urumqi
# Processing Record 4 of Set 4 | bredasdorp
# Processing Record 5 of Set 4 | bonavista
# Processing Record 6 of Set 4 | bandiagara
# Processing Record 7 of Set 4 | pisco
# Processing Record 8 of Set 4 | laredo
# Processing Record 9 of Set 4 | waingapu
# Processing Record 10 of Set 4 | antsohihy
# Processing Record 11 of Set 4 | ust-kut
# Processing Record 12 of Set 4 | yarada
# Processing Record 13 of Set 4 | dudinka
# Processing Record 14 of Set 4 | abha
# Processing Record 15 of Set 4 | beloha
# Processing Record 16 of Set 4 | tuatapere
# Processing Record 17 of Set 4 | trairi
# Processing Record 18 of Set 4 | thompson
# Processing Record 19 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 4 | luderitz
# Processing Record 21 of Set 4 | temnikov
# Processing Record 22 of Set 4 | chuy
# Processing Record 23 of Set 4 | manokwari
# Processing Record 24 of Set 4 | marsa matruh
# Processing Record 25 of Set 4 | mahebourg
# Processing Record 26 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 4 | lompoc
# Processing Record 29 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 4 | vanavara
# Processing Record 31 of Set 4 | gazanjyk
# Processing Record 32 of Set 4 | albina
# Processing Record 33 of Set 4 | adrar
# Processing Record 34 of Set 4 | avarua
# Processing Record 35 of Set 4 | shamkhal
# Processing Record 36 of Set 4 | tuxtla
# Processing Record 37 of Set 4 | slave lake
# Processing Record 38 of Set 4 | nikolskoye
# Processing Record 39 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 4 | lazaro cardenas
# Processing Record 41 of Set 4 | linxia
# Processing Record 42 of Set 4 | tateyama
# Processing Record 43 of Set 4 | aripuana
# Processing Record 44 of Set 4 | waddan
# Processing Record 45 of Set 4 | swellendam
# Processing Record 46 of Set 4 | mayo
# Processing Record 47 of Set 4 | piacabucu
# Processing Record 48 of Set 4 | qaqortoq
# Processing Record 49 of Set 4 | bluefield
# Processing Record 50 of Set 4 | reitz
# Processing Record 1 of Set 5 | nemuro
# Processing Record 2 of Set 5 | ginir
# Processing Record 3 of Set 5 | northam
# Processing Record 4 of Set 5 | lavrentiya
# Processing Record 5 of Set 5 | gigmoto
# Processing Record 6 of Set 5 | bulungu
# Processing Record 7 of Set 5 | ulaangom
# Processing Record 8 of Set 5 | ilulissat
# Processing Record 9 of Set 5 | cam ranh
# Processing Record 10 of Set 5 | kirakira
# Processing Record 11 of Set 5 | kankon
# Processing Record 12 of Set 5 | sarkand
# Processing Record 13 of Set 5 | nelson bay
# Processing Record 14 of Set 5 | acapulco
# Processing Record 15 of Set 5 | mount isa
# Processing Record 16 of Set 5 | hare bay
# Processing Record 17 of Set 5 | ust-maya
# Processing Record 18 of Set 5 | sol-iletsk
# Processing Record 19 of Set 5 | neryungri
# Processing Record 20 of Set 5 | khowai
# Processing Record 21 of Set 5 | mirnyy
# Processing Record 22 of Set 5 | puerto carreno
# Processing Record 23 of Set 5 | sierra vista
# Processing Record 24 of Set 5 | san quintin
# Processing Record 25 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 5 | qingdao
# Processing Record 27 of Set 5 | launceston
# Processing Record 28 of Set 5 | torbay
# Processing Record 29 of Set 5 | kondopoga
# Processing Record 30 of Set 5 | churapcha
# Processing Record 31 of Set 5 | jamestown
# Processing Record 32 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 5 | asyut
# Processing Record 34 of Set 5 | gizo
# Processing Record 35 of Set 5 | sabha
# Processing Record 36 of Set 5 | tigil
# Processing Record 37 of Set 5 | alyangula
# Processing Record 38 of Set 5 | mana
# Processing Record 39 of Set 5 | kijang
# Processing Record 40 of Set 5 | san policarpo
# Processing Record 41 of Set 5 | ponta do sol
# Processing Record 42 of Set 5 | mongoumba
# Processing Record 43 of Set 5 | amapa
# Processing Record 44 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 5 | alice springs
# Processing Record 46 of Set 5 | port hedland
# Processing Record 47 of Set 5 | lagoa
# Processing Record 48 of Set 5 | chitapur
# Processing Record 49 of Set 5 | victoria
# Processing Record 50 of Set 5 | tiarei
# Processing Record 1 of Set 6 | bilma
# Processing Record 2 of Set 6 | gogrial
# Processing Record 3 of Set 6 | harper
# Processing Record 4 of Set 6 | nanortalik
# Processing Record 5 of Set 6 | katsuura
# Processing Record 6 of Set 6 | imbituba
# Processing Record 7 of Set 6 | krasnaya gora
# Processing Record 8 of Set 6 | kantang
# Processing Record 9 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 6 | borisoglebsk
# Processing Record 11 of Set 6 | port elizabeth
# Processing Record 12 of Set 6 | rosetta
# Processing Record 13 of Set 6 | boa vista
# Processing Record 14 of Set 6 | marzuq
# Processing Record 15 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 6 | ahipara
# Processing Record 17 of Set 6 | rapid valley
# Processing Record 18 of Set 6 | sao joao da barra
# Processing Record 19 of Set 6 | singaraja
# Processing Record 20 of Set 6 | axim
# Processing Record 21 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 6 | tromso
# Processing Record 23 of Set 6 | sile
# Processing Record 24 of Set 6 | gushikawa
# Processing Record 25 of Set 6 | trogir
# Processing Record 26 of Set 6 | fortuna
# Processing Record 27 of Set 6 | adeje
# Processing Record 28 of Set 6 | bidar
# Processing Record 29 of Set 6 | lagos
# Processing Record 30 of Set 6 | murray bridge
# Processing Record 31 of Set 6 | lebu
# Processing Record 32 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 33 of Set 6 | kawalu
# Processing Record 34 of Set 6 | slobodskoy
# Processing Record 35 of Set 6 | pervomayskiy
# Processing Record 36 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 6 | north bend
# Processing Record 38 of Set 6 | elizabeth city
# Processing Record 39 of Set 6 | taksimo
# Processing Record 40 of Set 6 | chapleau
# Processing Record 41 of Set 6 | melito di porto salvo
# Processing Record 42 of Set 6 | half moon bay
# Processing Record 43 of Set 6 | north platte
# Processing Record 44 of Set 6 | alghero
# Processing Record 45 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 46 of Set 6 | broome
# Processing Record 47 of Set 6 | airai
# Processing Record 48 of Set 6 | ushumun
# Processing Record 49 of Set 6 | abnub
# Processing Record 50 of Set 6 | lodwar
# Processing Record 1 of Set 7 | aksu
# Processing Record 2 of Set 7 | verkhnevilyuysk
# Processing Record 3 of Set 7 | simbahan
# Processing Record 4 of Set 7 | abu samrah
# Processing Record 5 of Set 7 | okhotsk
# Processing Record 6 of Set 7 | naze
# Processing Record 7 of Set 7 | ocala
# Processing Record 8 of Set 7 | sigli
# Processing Record 9 of Set 7 | el badari
# City not found. Skipping...
# Processing Record 10 of Set 7 | kirksville
# Processing Record 11 of Set 7 | zeya
# Processing Record 12 of Set 7 | anzio
# Processing Record 13 of Set 7 | talnakh
# Processing Record 14 of Set 7 | shahr-e babak
# Processing Record 15 of Set 7 | ambon
# Processing Record 16 of Set 7 | lieksa
# Processing Record 17 of Set 7 | staryy nadym
# Processing Record 18 of Set 7 | kulhudhuffushi
# Processing Record 19 of Set 7 | iqaluit
# Processing Record 20 of Set 7 | rawson
# Processing Record 21 of Set 7 | pacora
# Processing Record 22 of Set 7 | burgeo
# Processing Record 23 of Set 7 | graaff-reinet
# Processing Record 24 of Set 7 | hambantota
# Processing Record 25 of Set 7 | impfondo
# Processing Record 26 of Set 7 | foz
# Processing Record 27 of Set 7 | gat
# Processing Record 28 of Set 7 | aranjuez
# Processing Record 29 of Set 7 | aconibe
# Processing Record 30 of Set 7 | borovoy
# Processing Record 31 of Set 7 | poum
# Processing Record 32 of Set 7 | isoka
# Processing Record 33 of Set 7 | ust-kuyga
# Processing Record 34 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 35 of Set 7 | gamba
# Processing Record 36 of Set 7 | hanting
# Processing Record 37 of Set 7 | udachnyy
# Processing Record 38 of Set 7 | la ronge
# Processing Record 39 of Set 7 | najran
# Processing Record 40 of Set 7 | bathsheba
# Processing Record 41 of Set 7 | nome
# Processing Record 42 of Set 7 | beringovskiy
# Processing Record 43 of Set 7 | media luna
# Processing Record 44 of Set 7 | atar
# Processing Record 45 of Set 7 | baglung
# Processing Record 46 of Set 7 | dasoguz
# Processing Record 47 of Set 7 | geraldton
# Processing Record 48 of Set 7 | aklavik
# Processing Record 49 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 50 of Set 7 | belogorsk
# Processing Record 1 of Set 8 | orlandia
# Processing Record 2 of Set 8 | los llanos de aridane
# Processing Record 3 of Set 8 | manado
# Processing Record 4 of Set 8 | katangli
# Processing Record 5 of Set 8 | saint-pierre
# Processing Record 6 of Set 8 | linfen
# Processing Record 7 of Set 8 | uthal
# Processing Record 8 of Set 8 | kinablangan
# Processing Record 9 of Set 8 | margate
# Processing Record 10 of Set 8 | boqueirao
# Processing Record 11 of Set 8 | maceio
# Processing Record 12 of Set 8 | nyimba
# Processing Record 13 of Set 8 | tiznit
# Processing Record 14 of Set 8 | talaya
# Processing Record 15 of Set 8 | kavaratti
# Processing Record 16 of Set 8 | lokosovo
# Processing Record 17 of Set 8 | shimoda
# Processing Record 18 of Set 8 | ovalle
# Processing Record 19 of Set 8 | muisne
# Processing Record 20 of Set 8 | raudeberg
# Processing Record 21 of Set 8 | teeli
# Processing Record 22 of Set 8 | comodoro rivadavia
# Processing Record 23 of Set 8 | oranjemund
# Processing Record 24 of Set 8 | turbat
# Processing Record 25 of Set 8 | coahuayana
# Processing Record 26 of Set 8 | kourou
# Processing Record 27 of Set 8 | portland
# Processing Record 28 of Set 8 | dingle
# Processing Record 29 of Set 8 | brandon
# Processing Record 30 of Set 8 | keelung
# Processing Record 31 of Set 8 | sistranda
# Processing Record 32 of Set 8 | kindu
# Processing Record 33 of Set 8 | seymchan
# Processing Record 34 of Set 8 | blue springs
# Processing Record 35 of Set 8 | san juan de abajo
# Processing Record 36 of Set 8 | korla
# Processing Record 37 of Set 8 | burnie
# Processing Record 38 of Set 8 | namatanai
# Processing Record 39 of Set 8 | carlsbad
# Processing Record 40 of Set 8 | yar-sale
# Processing Record 41 of Set 8 | pascagoula
# Processing Record 42 of Set 8 | ayagoz
# Processing Record 43 of Set 8 | turukhansk
# Processing Record 44 of Set 8 | kumano
# Processing Record 45 of Set 8 | worthington
# Processing Record 46 of Set 8 | tautira
# Processing Record 47 of Set 8 | camopi
# Processing Record 48 of Set 8 | tostamaa
# City not found. Skipping...
# Processing Record 49 of Set 8 | santa isabel do rio negro
# Processing Record 50 of Set 8 | akyab
# Processing Record 1 of Set 9 | durban
# Processing Record 2 of Set 9 | qeshm
# Processing Record 3 of Set 9 | byron bay
# Processing Record 4 of Set 9 | dogondoutchi
# Processing Record 5 of Set 9 | asopos
# Processing Record 6 of Set 9 | kavieng
# Processing Record 7 of Set 9 | totness
# Processing Record 8 of Set 9 | svetlyy
# Processing Record 9 of Set 9 | saskylakh
# Processing Record 10 of Set 9 | guerrero negro
# Processing Record 11 of Set 9 | vikhorevka
# Processing Record 12 of Set 9 | madimba
# Processing Record 13 of Set 9 | buraydah
# Processing Record 14 of Set 9 | kushmurun
# Processing Record 15 of Set 9 | kununurra
# Processing Record 16 of Set 9 | matagami
# Processing Record 17 of Set 9 | artyom
# Processing Record 18 of Set 9 | lata
# Processing Record 19 of Set 9 | buchanan
# Processing Record 20 of Set 9 | kropotkin
# Processing Record 21 of Set 9 | kastamonu
# Processing Record 22 of Set 9 | bonfim
# Processing Record 23 of Set 9 | san felipe
# Processing Record 24 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 9 | hofn
# Processing Record 26 of Set 9 | faya
# Processing Record 27 of Set 9 | rio gallegos
# Processing Record 28 of Set 9 | zakamensk
# Processing Record 29 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 30 of Set 9 | kruisfontein
# Processing Record 31 of Set 9 | teguise
# Processing Record 32 of Set 9 | qasigiannguit
# Processing Record 33 of Set 9 | strezhevoy
# Processing Record 34 of Set 9 | padang
# Processing Record 35 of Set 9 | brae
# Processing Record 36 of Set 9 | acari
# Processing Record 37 of Set 9 | el carmen
# Processing Record 38 of Set 9 | natchitoches
# Processing Record 39 of Set 9 | jalu
# Processing Record 40 of Set 9 | sunggal
# Processing Record 41 of Set 9 | kutum
# Processing Record 42 of Set 9 | veraval
# Processing Record 43 of Set 9 | caravelas
# Processing Record 44 of Set 9 | ciudad bolivar
# Processing Record 45 of Set 9 | baherden
# Processing Record 46 of Set 9 | ulvila
# Processing Record 47 of Set 9 | yamada
# Processing Record 48 of Set 9 | balkanabat
# Processing Record 49 of Set 9 | kristinehamn
# Processing Record 50 of Set 9 | severo-kurilsk
# Processing Record 1 of Set 10 | isla vista
# Processing Record 2 of Set 10 | pedernales
# Processing Record 3 of Set 10 | treinta y tres
# Processing Record 4 of Set 10 | hervey bay
# Processing Record 5 of Set 10 | autun
# Processing Record 6 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 7 of Set 10 | rudbar
# Processing Record 8 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 9 of Set 10 | chapais
# Processing Record 10 of Set 10 | maningrida
# Processing Record 11 of Set 10 | saint-augustin
# Processing Record 12 of Set 10 | huarmey
# Processing Record 13 of Set 10 | norfolk
# Processing Record 14 of Set 10 | pokhara
# Processing Record 15 of Set 10 | nzega
# Processing Record 16 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 10 | algete
# Processing Record 19 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 21 of Set 10 | numan
# Processing Record 22 of Set 10 | takoradi
# Processing Record 23 of Set 10 | trincomalee
# Processing Record 24 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 10 | garowe
# Processing Record 26 of Set 10 | mareeba
# Processing Record 27 of Set 10 | santa ana
# Processing Record 28 of Set 10 | oga
# Processing Record 29 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 30 of Set 10 | codrington
# Processing Record 31 of Set 10 | letlhakeng
# Processing Record 32 of Set 10 | ratnagiri
# Processing Record 33 of Set 10 | vila franca do campo
# Processing Record 34 of Set 10 | mogadishu
# Processing Record 35 of Set 10 | rendsburg
# Processing Record 36 of Set 10 | east foothills
# Processing Record 37 of Set 10 | luangwa
# Processing Record 38 of Set 10 | jumla
# Processing Record 39 of Set 10 | torit
# Processing Record 40 of Set 10 | sosnovo-ozerskoye
# Processing Record 41 of Set 10 | nizwa
# Processing Record 42 of Set 10 | aranda de duero
# Processing Record 43 of Set 10 | carlisle
# Processing Record 44 of Set 10 | tottori
# Processing Record 45 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 46 of Set 10 | kahului
# Processing Record 47 of Set 10 | salekhard
# Processing Record 48 of Set 10 | labuhan
# Processing Record 49 of Set 10 | tinambacan
# Processing Record 50 of Set 10 | narodychi
# Processing Record 1 of Set 11 | mwanza
# Processing Record 2 of Set 11 | victor harbor
# Processing Record 3 of Set 11 | esna
# Processing Record 4 of Set 11 | pietarsaari
# Processing Record 5 of Set 11 | coquimbo
# Processing Record 6 of Set 11 | houma
# Processing Record 7 of Set 11 | belaya gora
# Processing Record 8 of Set 11 | thinadhoo
# Processing Record 9 of Set 11 | bakchar
# Processing Record 10 of Set 11 | tempio pausania
# Processing Record 11 of Set 11 | skjervoy
# Processing Record 12 of Set 11 | gardan diwal
# City not found. Skipping...
# Processing Record 13 of Set 11 | bud
# Processing Record 14 of Set 11 | broken hill
# Processing Record 15 of Set 11 | winnemucca
# Processing Record 16 of Set 11 | bubaque
# Processing Record 17 of Set 11 | tadine
# Processing Record 18 of Set 11 | tafresh
# Processing Record 19 of Set 11 | maiduguri
# Processing Record 20 of Set 11 | pacific grove
# Processing Record 21 of Set 11 | hasaki
# Processing Record 22 of Set 11 | vicente guerrero
# Processing Record 23 of Set 11 | oriximina
# Processing Record 24 of Set 11 | pitimbu
# Processing Record 25 of Set 11 | jiexiu
# Processing Record 26 of Set 11 | meadow lake
# Processing Record 27 of Set 11 | gisborne
# Processing Record 28 of Set 11 | makakilo city
# Processing Record 29 of Set 11 | sao joao do piaui
# Processing Record 30 of Set 11 | vardo
# Processing Record 31 of Set 11 | jatiroto
# Processing Record 32 of Set 11 | cozumel
# Processing Record 33 of Set 11 | port augusta
# Processing Record 34 of Set 11 | grand forks
# Processing Record 35 of Set 11 | chicama
# Processing Record 36 of Set 11 | teixoso
# Processing Record 37 of Set 11 | itarema
# Processing Record 38 of Set 11 | bandar
# Processing Record 39 of Set 11 | nagornyy
# Processing Record 40 of Set 11 | mogadouro
# Processing Record 41 of Set 11 | joroan
# Processing Record 42 of Set 11 | constitucion
# Processing Record 43 of Set 11 | kilosa
# Processing Record 44 of Set 11 | mackay
# Processing Record 45 of Set 11 | erzincan
# Processing Record 46 of Set 11 | tikapur
# Processing Record 47 of Set 11 | port macquarie
# Processing Record 48 of Set 11 | xuddur
# Processing Record 49 of Set 11 | sibolga
# Processing Record 50 of Set 11 | kampong cham
# Processing Record 1 of Set 12 | concordia
# Processing Record 2 of Set 12 | buenos aires
# Processing Record 3 of Set 12 | komsomolskiy
# Processing Record 4 of Set 12 | capuluan
# Processing Record 5 of Set 12 | bara
# Processing Record 6 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 8 of Set 12 | san juan
# Processing Record 9 of Set 12 | chama
# Processing Record 10 of Set 12 | belyy yar
# Processing Record 11 of Set 12 | pizarro
# Processing Record 12 of Set 12 | coari
# Processing Record 13 of Set 12 | tucupita
# Processing Record 14 of Set 12 | suruc
# Processing Record 15 of Set 12 | dubai
# Processing Record 16 of Set 12 | aras
# Processing Record 17 of Set 12 | otane
# Processing Record 18 of Set 12 | benghazi
# Processing Record 19 of Set 12 | parabel
# Processing Record 20 of Set 12 | mazagao
# Processing Record 21 of Set 12 | corinto
# Processing Record 22 of Set 12 | qom
# Processing Record 23 of Set 12 | nouakchott
# Processing Record 24 of Set 12 | meulaboh
# Processing Record 25 of Set 12 | san cristobal
# Processing Record 26 of Set 12 | kalamare
# Processing Record 27 of Set 12 | tura
# Processing Record 28 of Set 12 | sinnamary
# Processing Record 29 of Set 12 | hope
# Processing Record 30 of Set 12 | vavozh
# Processing Record 31 of Set 12 | hitoyoshi
# Processing Record 32 of Set 12 | dakar
# Processing Record 33 of Set 12 | anadyr
# Processing Record 34 of Set 12 | nara
# Processing Record 35 of Set 12 | zheshart
# Processing Record 36 of Set 12 | pekan
# Processing Record 37 of Set 12 | opuwo
# Processing Record 38 of Set 12 | nova olimpia
# Processing Record 39 of Set 12 | taganak
# Processing Record 40 of Set 12 | lasa
# Processing Record 41 of Set 12 | pochutla
# Processing Record 42 of Set 12 | peniche
# Processing Record 43 of Set 12 | niksic
# Processing Record 44 of Set 12 | mehamn
# Processing Record 45 of Set 12 | hobyo
# Processing Record 46 of Set 12 | vestmanna
# Processing Record 47 of Set 12 | nenjiang
# Processing Record 48 of Set 12 | isangel
# Processing Record 49 of Set 12 | vanderhoof
# Processing Record 50 of Set 12 | xingyi
# Processing Record 1 of Set 13 | karratha
# Processing Record 2 of Set 13 | zhigansk
# Processing Record 3 of Set 13 | pafos
# Processing Record 4 of Set 13 | portlethen
# Processing Record 5 of Set 13 | landang
# City not found. Skipping...
# Processing Record 6 of Set 13 | piet retief
# Processing Record 7 of Set 13 | hualmay
# Processing Record 8 of Set 13 | luchenza
# Processing Record 9 of Set 13 | nioki
# Processing Record 10 of Set 13 | sao filipe
# Processing Record 11 of Set 13 | esmeraldas
# Processing Record 12 of Set 13 | prince rupert
# Processing Record 13 of Set 13 | adre
# Processing Record 14 of Set 13 | itamaraca
# Processing Record 15 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 13 | harnoli
# Processing Record 17 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 13 | ust-nera
# Processing Record 19 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 20 of Set 13 | biograd na moru
# Processing Record 21 of Set 13 | gavrilov posad
# Processing Record 22 of Set 13 | dujuma
# City not found. Skipping...
# Processing Record 23 of Set 13 | douentza
# Processing Record 24 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 25 of Set 13 | roebourne
# Processing Record 26 of Set 13 | ponta delgada
# Processing Record 27 of Set 13 | sao gotardo
# Processing Record 28 of Set 13 | charlottesville
# Processing Record 29 of Set 13 | cabedelo
# Processing Record 30 of Set 13 | caete
# Processing Record 31 of Set 13 | stavern
# Processing Record 32 of Set 13 | rundu
# Processing Record 33 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 34 of Set 13 | caronport
# Processing Record 35 of Set 13 | maldonado
# Processing Record 36 of Set 13 | potiskum
# Processing Record 37 of Set 13 | ilorin
# Processing Record 38 of Set 13 | tulsipur
# Processing Record 39 of Set 13 | bodden town
# Processing Record 40 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 41 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 42 of Set 13 | nanakuli
# Processing Record 43 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 13 | ongandjera
# Processing Record 45 of Set 13 | anamur
# Processing Record 46 of Set 13 | vao
# Processing Record 47 of Set 13 | tornio
# Processing Record 48 of Set 13 | guilin
# Processing Record 49 of Set 13 | nortelandia
# Processing Record 50 of Set 13 | yining
# Processing Record 1 of Set 14 | dunedin
# Processing Record 2 of Set 14 | pangnirtung
# Processing Record 3 of Set 14 | aykhal
# Processing Record 4 of Set 14 | de-kastri
# Processing Record 5 of Set 14 | rocha
# Processing Record 6 of Set 14 | beppu
# Processing Record 7 of Set 14 | riyadh
# Processing Record 8 of Set 14 | alihe
# Processing Record 9 of Set 14 | nisia floresta
# Processing Record 10 of Set 14 | shenjiamen
# Processing Record 11 of Set 14 | talavera
# Processing Record 12 of Set 14 | gurupi
# Processing Record 13 of Set 14 | santiago del estero
# Processing Record 14 of Set 14 | samarai
# Processing Record 15 of Set 14 | vitim
# Processing Record 16 of Set 14 | bocaiuva
# Processing Record 17 of Set 14 | south lake tahoe
# Processing Record 18 of Set 14 | egvekinot
# Processing Record 19 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 20 of Set 14 | formosa do rio preto
# Processing Record 21 of Set 14 | vila velha
# Processing Record 22 of Set 14 | taltal
# Processing Record 23 of Set 14 | todos santos
# Processing Record 24 of Set 14 | yarmouth
# Processing Record 25 of Set 14 | stockelsdorf
# Processing Record 26 of Set 14 | altay
# Processing Record 27 of Set 14 | springbok
# Processing Record 28 of Set 14 | palmer
# Processing Record 29 of Set 14 | lamar
# Processing Record 30 of Set 14 | toora-khem
# Processing Record 31 of Set 14 | caraballeda
# Processing Record 32 of Set 14 | mahon
# Processing Record 33 of Set 14 | werda
# Processing Record 34 of Set 14 | matara
# Processing Record 35 of Set 14 | fuling
# Processing Record 36 of Set 14 | kenai
# Processing Record 37 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 14 | taft
# Processing Record 39 of Set 14 | maumere
# Processing Record 40 of Set 14 | pandan
# Processing Record 41 of Set 14 | mahajanga
# Processing Record 42 of Set 14 | lulea
# Processing Record 43 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 14 | marawi
# Processing Record 45 of Set 14 | baia de aries
# Processing Record 46 of Set 14 | muroto
# Processing Record 47 of Set 14 | himora
# City not found. Skipping...
# Processing Record 48 of Set 14 | gondanglegi
# Processing Record 49 of Set 14 | port hardy
# Processing Record 50 of Set 14 | carutapera
# Processing Record 1 of Set 15 | ponca city
# Processing Record 2 of Set 15 | tokur
# Processing Record 3 of Set 15 | saint anthony
# Processing Record 4 of Set 15 | bollnas
# Processing Record 5 of Set 15 | pihani
# Processing Record 6 of Set 15 | tocopilla
# Processing Record 7 of Set 15 | ntungamo
# Processing Record 8 of Set 15 | berlevag
# Processing Record 9 of Set 15 | lingao
# Processing Record 10 of Set 15 | nalut
# Processing Record 11 of Set 15 | iringa
# Processing Record 12 of Set 15 | barahona
# Processing Record 13 of Set 15 | nizhniy kuranakh
# Processing Record 14 of Set 15 | laurel
# Processing Record 15 of Set 15 | ayios matthaios
# City not found. Skipping...
# Processing Record 16 of Set 15 | gimli
# Processing Record 17 of Set 15 | santa cruz
# Processing Record 18 of Set 15 | luchegorsk
# Processing Record 19 of Set 15 | saint marys
# Processing Record 20 of Set 15 | whitefish
# Processing Record 21 of Set 15 | causapscal
# Processing Record 22 of Set 15 | wanning
# Processing Record 23 of Set 15 | pula
# Processing Record 24 of Set 15 | lentekhi
# Processing Record 25 of Set 15 | aksay
# Processing Record 26 of Set 15 | bukachacha
# Processing Record 27 of Set 15 | aix-en-provence
# Processing Record 28 of Set 15 | hovd
# Processing Record 29 of Set 15 | daru
# Processing Record 30 of Set 15 | paita
# Processing Record 31 of Set 15 | pangkalanbuun
# Processing Record 32 of Set 15 | vakhrushev
# Processing Record 33 of Set 15 | colares
# Processing Record 34 of Set 15 | henties bay
# Processing Record 35 of Set 15 | iskateley
# Processing Record 36 of Set 15 | ixtapa
# Processing Record 37 of Set 15 | noumea
# Processing Record 38 of Set 15 | tabriz
# Processing Record 39 of Set 15 | katherine
# Processing Record 40 of Set 15 | ordu
# Processing Record 41 of Set 15 | makat
# Processing Record 42 of Set 15 | uvat
# Processing Record 43 of Set 15 | prado
# Processing Record 44 of Set 15 | talas
# Processing Record 45 of Set 15 | te anau
# -----------------------------
# Data Retrieval Complete

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country                 Date    Lat     Lng  Max Temp  \
# 0     Cherskiy      RU  2020-09-27 00:36:55  68.75  161.30     42.35
# 1    Ostrovnoy      RU  2020-09-27 00:36:56  68.05   39.51     42.39
# 2      College      US  2020-09-27 00:36:56  64.86 -147.80     53.60
# 3  Farafangana      MG  2020-09-27 00:36:56 -22.82   47.83     67.51
# 4      Estelle      US  2020-09-27 00:36:56  29.85  -90.11     79.00
# 5       Kodiak      US  2020-09-27 00:36:56  57.79 -152.41     51.80
# 6       Vostok      RU  2020-09-27 00:36:57  46.49  135.88     52.70
# 7      Waipawa      NZ  2020-09-27 00:36:57 -41.41  175.52     59.00
# 8    Carnarvon      AU  2020-09-27 00:36:57 -24.87  113.63     68.00
# 9  New Norfolk      AU  2020-09-27 00:36:57 -42.78  147.06     52.00
#
#    Humidity  Cloudiness  Wind Speed       Description
# 0        69           0       19.66         clear sky
# 1        87         100       14.20   overcast clouds
# 2        58          40        3.36  scattered clouds
# 3        86           9        9.71         clear sky
# 4        94           1        3.36         clear sky
# 5        76          20        8.05        few clouds
# 6        57           1        5.88         clear sky
# 7        72          78       29.97     broken clouds
# 8        64          11       13.87        few clouds
# 9        65          77        3.00     broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
