# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the time module.
import time

# Import the requests library.
import requests

# Import the API key.
from config1 import weather_API_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_API_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
  
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
 
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0].get('description')
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
       
        # Append the city information into city_data list.
                      
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description,                          
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | xining
# Processing Record 4 of Set 1 | touros
# Processing Record 5 of Set 1 | panaba
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | mar del plata
# Processing Record 8 of Set 1 | kemijarvi
# Processing Record 9 of Set 1 | vardo
# Processing Record 10 of Set 1 | chuy
# Processing Record 11 of Set 1 | talnakh
# Processing Record 12 of Set 1 | lusambo
# Processing Record 13 of Set 1 | tevaitoa
# Processing Record 14 of Set 1 | kaitangata
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | sao joao da barra
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | vilhena
# Processing Record 19 of Set 1 | moron
# Processing Record 20 of Set 1 | tsiroanomandidy
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | bekhteyevka
# Processing Record 23 of Set 1 | taltal
# Processing Record 24 of Set 1 | severo-kurilsk
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | arrecife
# Processing Record 27 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 1 | nanortalik
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | westport
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | lannion
# Processing Record 33 of Set 1 | tecoanapa
# Processing Record 34 of Set 1 | codrington
# Processing Record 35 of Set 1 | araouane
# Processing Record 36 of Set 1 | namatanai
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | quelimane
# Processing Record 40 of Set 1 | longyearbyen
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | benidorm
# Processing Record 44 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 1 | santa fe
# Processing Record 46 of Set 1 | kuala terengganu
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | tunduru
# City not found. Skipping...
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 2 | sergeyevka
# Processing Record 2 of Set 2 | nur
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | maniitsoq
# Processing Record 5 of Set 2 | monywa
# Processing Record 6 of Set 2 | samarai
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | aasiaat
# Processing Record 10 of Set 2 | port-gentil
# Processing Record 11 of Set 2 | sao francisco de assis
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | ugoofaaru
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 2 | malazgirt
# Processing Record 17 of Set 2 | port lincoln
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | pevek
# Processing Record 20 of Set 2 | ancud
# Processing Record 21 of Set 2 | torbay
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | avera
# Processing Record 24 of Set 2 | yulara
# Processing Record 25 of Set 2 | thompson
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | ilulissat
# Processing Record 28 of Set 2 | geraldton
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | richards bay
# Processing Record 32 of Set 2 | aykhal
# Processing Record 33 of Set 2 | oranjemund
# Processing Record 34 of Set 2 | cancun
# Processing Record 35 of Set 2 | vila velha
# Processing Record 36 of Set 2 | mehamn
# Processing Record 37 of Set 2 | iqaluit
# Processing Record 38 of Set 2 | gravelbourg
# Processing Record 39 of Set 2 | bluff
# Processing Record 40 of Set 2 | saskylakh
# Processing Record 41 of Set 2 | saldanha
# Processing Record 42 of Set 2 | verkh-usugli
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | domoni
# Processing Record 45 of Set 2 | muros
# Processing Record 46 of Set 2 | alofi
# Processing Record 47 of Set 2 | langsa
# Processing Record 48 of Set 2 | mahibadhoo
# Processing Record 49 of Set 2 | ponta do sol
# Processing Record 50 of Set 2 | saint-pierre
# Processing Record 1 of Set 3 | clyde river
# Processing Record 2 of Set 3 | nikolskoye
# Processing Record 3 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 3 | half moon bay
# Processing Record 5 of Set 3 | birao
# Processing Record 6 of Set 3 | hualmay
# Processing Record 7 of Set 3 | praya
# Processing Record 8 of Set 3 | santa maria da vitoria
# Processing Record 9 of Set 3 | mbandaka
# Processing Record 10 of Set 3 | gillette
# Processing Record 11 of Set 3 | wyndham
# Processing Record 12 of Set 3 | aanekoski
# Processing Record 13 of Set 3 | bonanza
# Processing Record 14 of Set 3 | porto novo
# Processing Record 15 of Set 3 | dzhebariki-khaya
# Processing Record 16 of Set 3 | fengrun
# Processing Record 17 of Set 3 | jaciara
# Processing Record 18 of Set 3 | varkkallai
# Processing Record 19 of Set 3 | klaksvik
# Processing Record 20 of Set 3 | sungaipenuh
# Processing Record 21 of Set 3 | darhan
# Processing Record 22 of Set 3 | itamaraju
# Processing Record 23 of Set 3 | hobyo
# Processing Record 24 of Set 3 | pangnirtung
# Processing Record 25 of Set 3 | hobart
# Processing Record 26 of Set 3 | coquimbo
# Processing Record 27 of Set 3 | marsh harbour
# Processing Record 28 of Set 3 | tasiilaq
# Processing Record 29 of Set 3 | vigeland
# Processing Record 30 of Set 3 | bengkulu
# Processing Record 31 of Set 3 | cajamarca
# Processing Record 32 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 3 | lazaro cardenas
# Processing Record 34 of Set 3 | san juan
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | gat
# Processing Record 37 of Set 3 | paracuru
# Processing Record 38 of Set 3 | limbuhan
# Processing Record 39 of Set 3 | labrea
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | poddorye
# Processing Record 42 of Set 3 | castro
# Processing Record 43 of Set 3 | port elizabeth
# Processing Record 44 of Set 3 | shenjiamen
# Processing Record 45 of Set 3 | cap-aux-meules
# Processing Record 46 of Set 3 | presidencia roque saenz pena
# Processing Record 47 of Set 3 | pacific grove
# Processing Record 48 of Set 3 | ribeira grande
# Processing Record 49 of Set 3 | mopipi
# Processing Record 50 of Set 3 | cidreira
# Processing Record 1 of Set 4 | cabo san lucas
# Processing Record 2 of Set 4 | dali
# Processing Record 3 of Set 4 | san miguel ixtahuacan
# Processing Record 4 of Set 4 | nalut
# Processing Record 5 of Set 4 | acaponeta
# Processing Record 6 of Set 4 | montelimar
# Processing Record 7 of Set 4 | camacha
# Processing Record 8 of Set 4 | cockburn town
# Processing Record 9 of Set 4 | krasnyy luch
# Processing Record 10 of Set 4 | lebu
# Processing Record 11 of Set 4 | kirakira
# Processing Record 12 of Set 4 | shebunino
# Processing Record 13 of Set 4 | lompoc
# Processing Record 14 of Set 4 | sioux lookout
# Processing Record 15 of Set 4 | tatarsk
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 18 of Set 4 | arraial do cabo
# Processing Record 19 of Set 4 | khatanga
# Processing Record 20 of Set 4 | alamogordo
# Processing Record 21 of Set 4 | bethel
# Processing Record 22 of Set 4 | alekseyevka
# Processing Record 23 of Set 4 | gannan
# Processing Record 24 of Set 4 | narsaq
# Processing Record 25 of Set 4 | marquette
# Processing Record 26 of Set 4 | hilo
# Processing Record 27 of Set 4 | esperance
# Processing Record 28 of Set 4 | viamao
# Processing Record 29 of Set 4 | karratha
# Processing Record 30 of Set 4 | narasannapeta
# Processing Record 31 of Set 4 | mayo
# Processing Record 32 of Set 4 | alta gracia
# Processing Record 33 of Set 4 | butaritari
# Processing Record 34 of Set 4 | matagami
# Processing Record 35 of Set 4 | pampas
# Processing Record 36 of Set 4 | tuktoyaktuk
# Processing Record 37 of Set 4 | suihua
# Processing Record 38 of Set 4 | hambantota
# Processing Record 39 of Set 4 | charters towers
# Processing Record 40 of Set 4 | nieves
# Processing Record 41 of Set 4 | bredasdorp
# Processing Record 42 of Set 4 | zhigansk
# Processing Record 43 of Set 4 | acapulco
# Processing Record 44 of Set 4 | gravdal
# Processing Record 45 of Set 4 | pisco
# Processing Record 46 of Set 4 | airai
# Processing Record 47 of Set 4 | hovd
# Processing Record 48 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 4 | trairi
# Processing Record 50 of Set 4 | cascais
# Processing Record 1 of Set 5 | tura
# Processing Record 2 of Set 5 | zyryanka
# Processing Record 3 of Set 5 | namibe
# Processing Record 4 of Set 5 | clarence town
# Processing Record 5 of Set 5 | nelson bay
# Processing Record 6 of Set 5 | dalbandin
# Processing Record 7 of Set 5 | san jeronimo
# Processing Record 8 of Set 5 | hermanus
# Processing Record 9 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 5 | petawawa
# Processing Record 11 of Set 5 | maxixe
# Processing Record 12 of Set 5 | riyadh
# Processing Record 13 of Set 5 | port moresby
# Processing Record 14 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 5 | arlit
# Processing Record 16 of Set 5 | shahrud
# Processing Record 17 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 19 of Set 5 | fengzhen
# Processing Record 20 of Set 5 | oeiras
# Processing Record 21 of Set 5 | keta
# Processing Record 22 of Set 5 | saint george
# Processing Record 23 of Set 5 | berlevag
# Processing Record 24 of Set 5 | muisne
# Processing Record 25 of Set 5 | evensk
# Processing Record 26 of Set 5 | tual
# Processing Record 27 of Set 5 | saquarema
# Processing Record 28 of Set 5 | qeshm
# Processing Record 29 of Set 5 | ibirama
# Processing Record 30 of Set 5 | provideniya
# Processing Record 31 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 32 of Set 5 | mamou
# Processing Record 33 of Set 5 | coihaique
# Processing Record 34 of Set 5 | kopyevo
# City not found. Skipping...
# Processing Record 35 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 36 of Set 5 | chokurdakh
# Processing Record 37 of Set 5 | naze
# Processing Record 38 of Set 5 | zaraza
# Processing Record 39 of Set 5 | meadow lake
# Processing Record 40 of Set 5 | los llanos de aridane
# Processing Record 41 of Set 5 | la ronge
# Processing Record 42 of Set 5 | vancouver
# Processing Record 43 of Set 5 | sinop
# Processing Record 44 of Set 5 | aswan
# Processing Record 45 of Set 5 | laguna
# Processing Record 46 of Set 5 | sinnamary
# Processing Record 47 of Set 5 | carballo
# Processing Record 48 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 49 of Set 5 | carnduff
# Processing Record 50 of Set 5 | constitucion
# Processing Record 1 of Set 6 | ciudad bolivar
# Processing Record 2 of Set 6 | beian
# Processing Record 3 of Set 6 | anloga
# Processing Record 4 of Set 6 | methoni
# Processing Record 5 of Set 6 | artyom
# Processing Record 6 of Set 6 | itarema
# Processing Record 7 of Set 6 | oskemen
# Processing Record 8 of Set 6 | irbit
# Processing Record 9 of Set 6 | auki
# Processing Record 10 of Set 6 | kahului
# Processing Record 11 of Set 6 | pedernales
# Processing Record 12 of Set 6 | lashio
# Processing Record 13 of Set 6 | baruun-urt
# Processing Record 14 of Set 6 | quatre cocos
# Processing Record 15 of Set 6 | atascadero
# Processing Record 16 of Set 6 | bismarck
# Processing Record 17 of Set 6 | marzuq
# Processing Record 18 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 6 | nenjiang
# Processing Record 20 of Set 6 | hervey bay
# Processing Record 21 of Set 6 | progreso
# Processing Record 22 of Set 6 | santa rosa
# Processing Record 23 of Set 6 | margate
# Processing Record 24 of Set 6 | comodoro rivadavia
# Processing Record 25 of Set 6 | souillac
# Processing Record 26 of Set 6 | katsuura
# Processing Record 27 of Set 6 | alyangula
# Processing Record 28 of Set 6 | syamzha
# Processing Record 29 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 30 of Set 6 | amuntai
# Processing Record 31 of Set 6 | paredon
# Processing Record 32 of Set 6 | nome
# Processing Record 33 of Set 6 | kedgwick
# Processing Record 34 of Set 6 | celestun
# Processing Record 35 of Set 6 | jutai
# Processing Record 36 of Set 6 | havoysund
# Processing Record 37 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 38 of Set 6 | college
# Processing Record 39 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 6 | bathsheba
# Processing Record 41 of Set 6 | faanui
# Processing Record 42 of Set 6 | atambua
# Processing Record 43 of Set 6 | coahuayana
# Processing Record 44 of Set 6 | akdepe
# Processing Record 45 of Set 6 | kollam
# Processing Record 46 of Set 6 | palembang
# Processing Record 47 of Set 6 | te anau
# Processing Record 48 of Set 6 | waingapu
# Processing Record 49 of Set 6 | sumter
# Processing Record 50 of Set 6 | pueblo nuevo
# Processing Record 1 of Set 7 | georgetown
# Processing Record 2 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 7 | kavieng
# Processing Record 4 of Set 7 | san patricio
# Processing Record 5 of Set 7 | dicabisagan
# Processing Record 6 of Set 7 | fukue
# Processing Record 7 of Set 7 | christchurch
# Processing Record 8 of Set 7 | sorgun
# Processing Record 9 of Set 7 | bilma
# Processing Record 10 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 7 | leningradskiy
# Processing Record 12 of Set 7 | matara
# Processing Record 13 of Set 7 | koslan
# Processing Record 14 of Set 7 | ono
# Processing Record 15 of Set 7 | badaojiang
# City not found. Skipping...
# Processing Record 16 of Set 7 | tautira
# Processing Record 17 of Set 7 | san pedro
# Processing Record 18 of Set 7 | gujar khan
# Processing Record 19 of Set 7 | severnoye
# Processing Record 20 of Set 7 | coldingham
# Processing Record 21 of Set 7 | fairbanks
# Processing Record 22 of Set 7 | faya
# Processing Record 23 of Set 7 | dafeng
# Processing Record 24 of Set 7 | laksar
# Processing Record 25 of Set 7 | kailua
# Processing Record 26 of Set 7 | turtkul
# City not found. Skipping...
# Processing Record 27 of Set 7 | visby
# Processing Record 28 of Set 7 | muzhi
# Processing Record 29 of Set 7 | walvis bay
# Processing Record 30 of Set 7 | vostok
# Processing Record 31 of Set 7 | norman wells
# Processing Record 32 of Set 7 | haines junction
# Processing Record 33 of Set 7 | pokaran
# Processing Record 34 of Set 7 | golubitskaya
# Processing Record 35 of Set 7 | gudalur
# Processing Record 36 of Set 7 | ewa beach
# Processing Record 37 of Set 7 | mahon
# Processing Record 38 of Set 7 | hamilton
# Processing Record 39 of Set 7 | prince george
# Processing Record 40 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 7 | tuatapere
# Processing Record 43 of Set 7 | kruisfontein
# Processing Record 44 of Set 7 | nueva concepcion
# Processing Record 45 of Set 7 | asfi
# Processing Record 46 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 7 | obo
# Processing Record 48 of Set 7 | grindavik
# Processing Record 49 of Set 7 | san carlos del zulia
# Processing Record 50 of Set 7 | puerto madero
# Processing Record 1 of Set 8 | guaymas
# Processing Record 2 of Set 8 | spremberg
# Processing Record 3 of Set 8 | lavrentiya
# Processing Record 4 of Set 8 | tessalit
# Processing Record 5 of Set 8 | ahualulco
# Processing Record 6 of Set 8 | caravelas
# Processing Record 7 of Set 8 | tokzar
# City not found. Skipping...
# Processing Record 8 of Set 8 | tromso
# Processing Record 9 of Set 8 | abalak
# Processing Record 10 of Set 8 | victoria
# Processing Record 11 of Set 8 | okitipupa
# Processing Record 12 of Set 8 | male
# Processing Record 13 of Set 8 | touba
# Processing Record 14 of Set 8 | bandarbeyla
# Processing Record 15 of Set 8 | chapais
# Processing Record 16 of Set 8 | pimentel
# Processing Record 17 of Set 8 | port hardy
# Processing Record 18 of Set 8 | prince rupert
# Processing Record 19 of Set 8 | dingle
# Processing Record 20 of Set 8 | eagle pass
# Processing Record 21 of Set 8 | manbij
# Processing Record 22 of Set 8 | carnarvon
# Processing Record 23 of Set 8 | vao
# Processing Record 24 of Set 8 | rock springs
# Processing Record 25 of Set 8 | osa
# Processing Record 26 of Set 8 | priiskovyy
# Processing Record 27 of Set 8 | boddam
# Processing Record 28 of Set 8 | tulungagung
# Processing Record 29 of Set 8 | carlagan
# Processing Record 30 of Set 8 | uyemskiy
# Processing Record 31 of Set 8 | kupang
# Processing Record 32 of Set 8 | jumla
# Processing Record 33 of Set 8 | sangar
# Processing Record 34 of Set 8 | indianola
# Processing Record 35 of Set 8 | bilibino
# Processing Record 36 of Set 8 | denpasar
# Processing Record 37 of Set 8 | jalu
# Processing Record 38 of Set 8 | havre-saint-pierre
# Processing Record 39 of Set 8 | cururupu
# Processing Record 40 of Set 8 | dukat
# Processing Record 41 of Set 8 | douglas
# Processing Record 42 of Set 8 | bongor
# Processing Record 43 of Set 8 | necochea
# Processing Record 44 of Set 8 | pouebo
# Processing Record 45 of Set 8 | noyabrsk
# Processing Record 46 of Set 8 | portland
# Processing Record 47 of Set 8 | huancavelica
# Processing Record 48 of Set 8 | kavkazskaya
# Processing Record 49 of Set 8 | cherdyn
# Processing Record 50 of Set 8 | sitka
# Processing Record 1 of Set 9 | oranjestad
# Processing Record 2 of Set 9 | vestmannaeyjar
# Processing Record 3 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 9 | venustiano carranza
# Processing Record 5 of Set 9 | yumen
# Processing Record 6 of Set 9 | puerto escondido
# Processing Record 7 of Set 9 | susangerd
# Processing Record 8 of Set 9 | palmer
# Processing Record 9 of Set 9 | sorland
# Processing Record 10 of Set 9 | vitim
# Processing Record 11 of Set 9 | horki
# Processing Record 12 of Set 9 | gayny
# Processing Record 13 of Set 9 | san-pedro
# Processing Record 14 of Set 9 | luderitz
# Processing Record 15 of Set 9 | tukrah
# Processing Record 16 of Set 9 | venkatagiri
# Processing Record 17 of Set 9 | hami
# Processing Record 18 of Set 9 | fortuna
# Processing Record 19 of Set 9 | salisbury
# Processing Record 20 of Set 9 | lorengau
# Processing Record 21 of Set 9 | awbari
# Processing Record 22 of Set 9 | ialibu
# Processing Record 23 of Set 9 | adre
# Processing Record 24 of Set 9 | the valley
# Processing Record 25 of Set 9 | flin flon
# Processing Record 26 of Set 9 | salug
# Processing Record 27 of Set 9 | fairmont
# Processing Record 28 of Set 9 | vicksburg
# Processing Record 29 of Set 9 | novaya bryan
# Processing Record 30 of Set 9 | khasan
# Processing Record 31 of Set 9 | kautokeino
# Processing Record 32 of Set 9 | biak
# Processing Record 33 of Set 9 | grande prairie
# Processing Record 34 of Set 9 | sokolo
# Processing Record 35 of Set 9 | zhangjiakou
# Processing Record 36 of Set 9 | meulaboh
# Processing Record 37 of Set 9 | taywarah
# Processing Record 38 of Set 9 | saraland
# Processing Record 39 of Set 9 | maroantsetra
# Processing Record 40 of Set 9 | batagay
# Processing Record 41 of Set 9 | lagoa
# Processing Record 42 of Set 9 | poum
# Processing Record 43 of Set 9 | lubu
# Processing Record 44 of Set 9 | furano
# Processing Record 45 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 9 | basoko
# Processing Record 47 of Set 9 | indramayu
# Processing Record 48 of Set 9 | natal
# Processing Record 49 of Set 9 | carauari
# Processing Record 50 of Set 9 | rumonge
# Processing Record 1 of Set 10 | port blair
# Processing Record 2 of Set 10 | bubaque
# Processing Record 3 of Set 10 | ayan
# Processing Record 4 of Set 10 | heihe
# Processing Record 5 of Set 10 | bambous virieux
# Processing Record 6 of Set 10 | pathein
# Processing Record 7 of Set 10 | nouakchott
# Processing Record 8 of Set 10 | de-kastri
# Processing Record 9 of Set 10 | carmen
# Processing Record 10 of Set 10 | guerrero negro
# Processing Record 11 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 12 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 10 | santa maria del oro
# Processing Record 14 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 10 | cozumel
# Processing Record 16 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 17 of Set 10 | dibulla
# Processing Record 18 of Set 10 | sibay
# Processing Record 19 of Set 10 | ostrovnoy
# Processing Record 20 of Set 10 | kaka
# Processing Record 21 of Set 10 | mayskiy
# Processing Record 22 of Set 10 | cardston
# Processing Record 23 of Set 10 | jarjis
# City not found. Skipping...
# Processing Record 24 of Set 10 | burica
# City not found. Skipping...
# Processing Record 25 of Set 10 | kristiansund
# Processing Record 26 of Set 10 | el angel
# Processing Record 27 of Set 10 | hasaki
# Processing Record 28 of Set 10 | antalaha
# Processing Record 29 of Set 10 | luwingu
# Processing Record 30 of Set 10 | tifton
# Processing Record 31 of Set 10 | brae
# Processing Record 32 of Set 10 | cayenne
# Processing Record 33 of Set 10 | disna
# Processing Record 34 of Set 10 | churachandpur
# Processing Record 35 of Set 10 | inirida
# Processing Record 36 of Set 10 | nakusp
# Processing Record 37 of Set 10 | noumea
# Processing Record 38 of Set 10 | anshun
# Processing Record 39 of Set 10 | manggar
# Processing Record 40 of Set 10 | ponta delgada
# Processing Record 41 of Set 10 | tomatlan
# Processing Record 42 of Set 10 | jiaojiang
# Processing Record 43 of Set 10 | khanpur
# Processing Record 44 of Set 10 | juan de acosta
# Processing Record 45 of Set 10 | kashi
# Processing Record 46 of Set 10 | fare
# Processing Record 47 of Set 10 | yagodnoye
# Processing Record 48 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 49 of Set 10 | khandyga
# Processing Record 50 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 11 | tiksi
# Processing Record 2 of Set 11 | sao felix do xingu
# Processing Record 3 of Set 11 | lubao
# Processing Record 4 of Set 11 | kingstown
# Processing Record 5 of Set 11 | belmonte
# Processing Record 6 of Set 11 | archidona
# Processing Record 7 of Set 11 | monclova
# Processing Record 8 of Set 11 | pandan
# Processing Record 9 of Set 11 | maltahohe
# Processing Record 10 of Set 11 | waldoboro
# Processing Record 11 of Set 11 | axim
# Processing Record 12 of Set 11 | tabou
# Processing Record 13 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 11 | abha
# Processing Record 15 of Set 11 | sinegorye
# Processing Record 16 of Set 11 | samarkand
# Processing Record 17 of Set 11 | krasnoarmeysk
# Processing Record 18 of Set 11 | solnechnyy
# Processing Record 19 of Set 11 | cherskiy
# Processing Record 20 of Set 11 | carutapera
# Processing Record 21 of Set 11 | imeni babushkina
# Processing Record 22 of Set 11 | kaman
# Processing Record 23 of Set 11 | bonavista
# Processing Record 24 of Set 11 | paamiut
# Processing Record 25 of Set 11 | krasnyy kut
# Processing Record 26 of Set 11 | three hills
# Processing Record 27 of Set 11 | kamra
# Processing Record 28 of Set 11 | mount isa
# Processing Record 29 of Set 11 | brownsville
# Processing Record 30 of Set 11 | atar
# Processing Record 31 of Set 11 | opuwo
# Processing Record 32 of Set 11 | beira
# Processing Record 33 of Set 11 | nyurba
# Processing Record 34 of Set 11 | husavik
# Processing Record 35 of Set 11 | periyapatti
# Processing Record 36 of Set 11 | doka
# Processing Record 37 of Set 11 | borogontsy
# Processing Record 38 of Set 11 | zapolyarnyy
# Processing Record 39 of Set 11 | kazanskaya
# Processing Record 40 of Set 11 | hyeres
# Processing Record 41 of Set 11 | ahipara
# Processing Record 42 of Set 11 | salinas
# Processing Record 43 of Set 11 | aklavik
# Processing Record 44 of Set 11 | dosso
# Processing Record 45 of Set 11 | hailar
# Processing Record 46 of Set 11 | okakarara
# Processing Record 47 of Set 11 | ihosy
# Processing Record 48 of Set 11 | andarab
# City not found. Skipping...
# Processing Record 49 of Set 11 | omsukchan
# Processing Record 50 of Set 11 | sur
# Processing Record 1 of Set 12 | dargaville
# Processing Record 2 of Set 12 | baghdad
# Processing Record 3 of Set 12 | preobrazheniye
# Processing Record 4 of Set 12 | berdigestyakh
# Processing Record 5 of Set 12 | ketchikan
# Processing Record 6 of Set 12 | tazovskiy
# Processing Record 7 of Set 12 | sabang
# Processing Record 8 of Set 12 | normandin
# Processing Record 9 of Set 12 | olafsvik
# Processing Record 10 of Set 12 | hofn
# Processing Record 11 of Set 12 | itoman
# Processing Record 12 of Set 12 | fort abbas
# Processing Record 13 of Set 12 | lasa
# Processing Record 14 of Set 12 | bridlington
# Processing Record 15 of Set 12 | pachino
# Processing Record 16 of Set 12 | agirish
# Processing Record 17 of Set 12 | la sarre
# Processing Record 18 of Set 12 | xinzhi
# Processing Record 19 of Set 12 | dauphin
# Processing Record 20 of Set 12 | carbonia
# Processing Record 21 of Set 12 | plettenberg bay
# Processing Record 22 of Set 12 | kattivakkam
# Processing Record 23 of Set 12 | wasilla
# Processing Record 24 of Set 12 | tulun
# Processing Record 25 of Set 12 | san ramon
# Processing Record 26 of Set 12 | abonnema
# Processing Record 27 of Set 12 | jati
# Processing Record 28 of Set 12 | salalah
# Processing Record 29 of Set 12 | sechura
# Processing Record 30 of Set 12 | qaqortoq
# Processing Record 31 of Set 12 | povenets
# Processing Record 32 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 33 of Set 12 | zabol
# Processing Record 34 of Set 12 | sao filipe
# Processing Record 35 of Set 12 | fuling
# Processing Record 36 of Set 12 | salym
# Processing Record 37 of Set 12 | mangrul pir
# Processing Record 38 of Set 12 | porto santo
# Processing Record 39 of Set 12 | mount gambier
# Processing Record 40 of Set 12 | anahuac
# Processing Record 41 of Set 12 | tateyama
# Processing Record 42 of Set 12 | gurupa
# Processing Record 43 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 44 of Set 12 | san andres
# Processing Record 45 of Set 12 | chalan
# Processing Record 46 of Set 12 | athabasca
# Processing Record 47 of Set 12 | kapustin yar
# Processing Record 48 of Set 12 | linqing
# Processing Record 49 of Set 12 | beloha
# Processing Record 50 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 1 of Set 13 | torbat-e jam
# Processing Record 2 of Set 13 | yerbogachen
# Processing Record 3 of Set 13 | taoudenni
# Processing Record 4 of Set 13 | broome
# Processing Record 5 of Set 13 | racine
# Processing Record 6 of Set 13 | padre bernardo
# Processing Record 7 of Set 13 | pierre
# Processing Record 8 of Set 13 | shelburne
# Processing Record 9 of Set 13 | wahiawa
# Processing Record 10 of Set 13 | saint-augustin
# Processing Record 11 of Set 13 | luangwa
# Processing Record 12 of Set 13 | sola
# Processing Record 13 of Set 13 | sisimiut
# Processing Record 14 of Set 13 | santa isabel do rio negro
# Processing Record 15 of Set 13 | zheleznodorozhnyy
# Processing Record 16 of Set 13 | ambilobe
# Processing Record 17 of Set 13 | balsas
# Processing Record 18 of Set 13 | tupik
# Processing Record 19 of Set 13 | luganville
# Processing Record 20 of Set 13 | kosya
# City not found. Skipping...
# Processing Record 21 of Set 13 | shakawe
# Processing Record 22 of Set 13 | santa maria
# Processing Record 23 of Set 13 | saint-joseph
# Processing Record 24 of Set 13 | rincon
# Processing Record 25 of Set 13 | dondo
# Processing Record 26 of Set 13 | bacalar
# Processing Record 27 of Set 13 | badou
# Processing Record 28 of Set 13 | manzhouli
# Processing Record 29 of Set 13 | zhezkazgan
# Processing Record 30 of Set 13 | rawson
# Processing Record 31 of Set 13 | port macquarie
# Processing Record 32 of Set 13 | tongchuan
# Processing Record 33 of Set 13 | chimbote
# Processing Record 34 of Set 13 | kiruna
# Processing Record 35 of Set 13 | north bend
# Processing Record 36 of Set 13 | tome
# Processing Record 37 of Set 13 | salamanca
# Processing Record 38 of Set 13 | mandalgovi
# Processing Record 39 of Set 13 | kununurra
# Processing Record 40 of Set 13 | jieshi
# Processing Record 41 of Set 13 | kamaishi
# Processing Record 42 of Set 13 | gao
# Processing Record 43 of Set 13 | vezirkopru
# Processing Record 44 of Set 13 | benicarlo
# Processing Record 45 of Set 13 | sokoni
# Processing Record 46 of Set 13 | teguise
# Processing Record 47 of Set 13 | rabak
# Processing Record 48 of Set 13 | spartanburg
# Processing Record 49 of Set 13 | mizque
# Processing Record 50 of Set 13 | mogadishu
# Processing Record 1 of Set 14 | chimoio
# Processing Record 2 of Set 14 | mitsamiouli
# Processing Record 3 of Set 14 | deputatskiy
# Processing Record 4 of Set 14 | kudahuvadhoo
# Processing Record 5 of Set 14 | ejido
# Processing Record 6 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 14 | labelle
# Processing Record 8 of Set 14 | bria
# Processing Record 9 of Set 14 | denau
# City not found. Skipping...
# Processing Record 10 of Set 14 | yaan
# Processing Record 11 of Set 14 | valdivia
# Processing Record 12 of Set 14 | nemuro
# Processing Record 13 of Set 14 | emba
# Processing Record 14 of Set 14 | ravar
# Processing Record 15 of Set 14 | mwinilunga
# Processing Record 16 of Set 14 | tubuala
# Processing Record 17 of Set 14 | amga
# Processing Record 18 of Set 14 | cedar city
# Processing Record 19 of Set 14 | el faiyum
# City not found. Skipping...
# Processing Record 20 of Set 14 | vung tau
# Processing Record 21 of Set 14 | warrington
# Processing Record 22 of Set 14 | naryan-mar
# Processing Record 23 of Set 14 | kawalu
# Processing Record 24 of Set 14 | gamba
# Processing Record 25 of Set 14 | ramgarh
# Processing Record 26 of Set 14 | areni
# Processing Record 27 of Set 14 | skelleftea
# Processing Record 28 of Set 14 | uglegorsk
# Processing Record 29 of Set 14 | stornoway
# Processing Record 30 of Set 14 | les cayes
# Processing Record 31 of Set 14 | fort wellington
# Processing Record 32 of Set 14 | barguzin
# Processing Record 33 of Set 14 | koundara
# Processing Record 34 of Set 14 | hampton
# Processing Record 35 of Set 14 | kargasok
# Processing Record 36 of Set 14 | camocim
# Processing Record 37 of Set 14 | neiafu
# Processing Record 38 of Set 14 | graaff-reinet
# Processing Record 39 of Set 14 | ughelli
# Processing Record 40 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 14 | alenquer
# Processing Record 42 of Set 14 | novikovo
# Processing Record 43 of Set 14 | zyryanovsk
# Processing Record 44 of Set 14 | miraflores
# Processing Record 45 of Set 14 | selishche
# Processing Record 46 of Set 14 | viedma
# Processing Record 47 of Set 14 | soc trang

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
